# %%
import pandas as pd

# Load the CSV file
file_path = 'combined.csv'  # replace with the path to your file
data = pd.read_csv(file_path)

# Print column count and column names
column_count = len(data.columns)
print(f"Number of Columns: {column_count}")
print(f"Column Names: {data.columns.tolist()}")

# Display the first 5 rows
data.head()
# Out:
# Number of Columns: 95
# Column Names: ['name', 'owner', 'description', 'language', 'forks_count', 'stargazers_count', 'events_url', 'tags_url', 'private', 'notifications_url', 'blobs_url', 'deployments_url', 'keys_url', 'archived', 'ssh_url', 'watchers', 'forks', 'contributors_url', 'releases_url', 'id', 'disabled', 'permissions', 'languages_url', 'git_commits_url', 'visibility', 'labels_url', 'fork', 'trees_url', 'mirror_url', 'is_template', 'web_commit_signoff_required', 'issue_events_url', 'subscription_url', 'stargazers_url', 'git_url', 'node_id', 'commits_url', 'subscribers_url', 'allow_forking', 'default_branch', 'has_downloads', 'assignees_url', 'comments_url', 'full_name', 'hooks_url', 'collaborators_url', 'contents_url', 'statuses_url', 'html_url', 'size', 'issue_comment_url', 'milestones_url', 'open_issues', 'watchers_count', 'git_refs_url', 'license', 'issues_url', 'svn_url', 'has_wiki', 'archive_url', 'has_issues', 'open_issues_count', 'downloads_url', 'pulls_url', 'owner.1', 'url', 'homepage', 'topics', 'created_at', 'clone_url', 'merges_url', 'branches_url', 'updated_at', 'git_tags_url', 'has_pages', 'forks_url', 'pushed_at', 'teams_url', 'has_projects', 'has_discussions', 'compare_url', 'actions', 'test_folder', 'automated_testing', 'howfairis_repository', 'howfairis_license', 'howfairis_registry', 'howfairis_citation', 'howfairis_checklist', 'date', 'organisation', 'researchGroup', 'fair_score', 'test', 'name;owner;description;language;forks_count;stargazers_count;events_url;tags_url;private;notifications_url;blobs_url;deployments_url;keys_url;archived;ssh_url;watchers;forks;contributors_url;releases_url;id;disabled;permissions;languages_url;git_commits_url;visibility;labels_url;fork;trees_url;mirror_url;is_template;web_commit_signoff_required;issue_events_url;subscription_url;stargazers_url;git_url;node_id;commits_url;subscribers_url;allow_forking;default_branch;has_downloads;assignees_url;comments_url;full_name;hooks_url;collaborators_url;contents_url;statuses_url;html_url;size;issue_comment_url;milestones_url;open_issues;watchers_count;git_refs_url;license;issues_url;svn_url;has_wiki;archive_url;has_issues;open_issues_count;downloads_url;pulls_url;owner;url;homepage;topics;created_at;clone_url;merges_url;branches_url;updated_at;git_tags_url;has_pages;forks_url;pushed_at;teams_url;has_projects;has_discussions;compare_url']
#              name                                              owner  \
# 0           Suite  {'login': 'Open-Systems-Pharmacology', 'id': 2...
# 1          PK-Sim  {'login': 'Open-Systems-Pharmacology', 'id': 2...
# 2            MoBi  {'login': 'Open-Systems-Pharmacology', 'id': 2...
# 3  Matlab-Toolbox  {'login': 'Open-Systems-Pharmacology', 'id': 2...
# 4       R-Toolbox  {'login': 'Open-Systems-Pharmacology', 'id': 2...
#
#                                          description          language  \
# 0             Open Systems Pharmacology Suite Setup   Rich Text Format
# 1  PK-Sim® is a comprehensive software tool for w...                C#
# 2  MoBi® is a software tool for multiscale physio...                C#
# 3  Collection of Matlab® functions for the proces...  Rich Text Format
# 4                                                NaN                 R
#
#    forks_count  stargazers_count  \
# 0         27.0              99.0
# 1         46.0              88.0
# 2          8.0              25.0
# 3          2.0               2.0
# 4          7.0               3.0
#
#                                           events_url  \
# 0  https://api.github.com/repos/Open-Systems-Phar...
# 1  https://api.github.com/repos/Open-Systems-Phar...
# 2  https://api.github.com/repos/Open-Systems-Phar...
# 3  https://api.github.com/repos/Open-Systems-Phar...
# 4  https://api.github.com/repos/Open-Systems-Phar...
#
#                                             tags_url private  \
# 0  https://api.github.com/repos/Open-Systems-Phar...   False
# 1  https://api.github.com/repos/Open-Systems-Phar...   False
# 2  https://api.github.com/repos/Open-Systems-Phar...   False
# 3  https://api.github.com/repos/Open-Systems-Phar...   False
# 4  https://api.github.com/repos/Open-Systems-Phar...   False
#
#                                    notifications_url  ... howfairis_license  \
# 0  https://api.github.com/repos/Open-Systems-Phar...  ...              True
# 1  https://api.github.com/repos/Open-Systems-Phar...  ...              True
# 2  https://api.github.com/repos/Open-Systems-Phar...  ...              True
# 3  https://api.github.com/repos/Open-Systems-Phar...  ...              True
# 4  https://api.github.com/repos/Open-Systems-Phar...  ...              True
#
#   howfairis_registry howfairis_citation howfairis_checklist        date  \
# 0              False              False               False  2023-08-11
# 1              False              False               False  2023-08-11
# 2              False              False               False  2023-08-11
# 3              False              False               False  2023-08-11
# 4              False              False               False  2023-08-11
#
#    organisation              researchGroup fair_score test  \
# 0       startup  open_systems_pharmacology        2.0  NaN
# 1       startup  open_systems_pharmacology        2.0  NaN
# 2       startup  open_systems_pharmacology        2.0  NaN
# 3       startup  open_systems_pharmacology        2.0  NaN
# 4       startup  open_systems_pharmacology        2.0  NaN
#
#    name;owner;description;language;forks_count;stargazers_count;events_url;tags_url;private;notifications_url;blobs_url;deployments_url;keys_url;archived;ssh_url;watchers;forks;contributors_url;releases_url;id;disabled;permissions;languages_url;git_commits_url;visibility;labels_url;fork;trees_url;mirror_url;is_template;web_commit_signoff_required;issue_events_url;subscription_url;stargazers_url;git_url;node_id;commits_url;subscribers_url;allow_forking;default_branch;has_downloads;assignees_url;comments_url;full_name;hooks_url;collaborators_url;contents_url;statuses_url;html_url;size;issue_comment_url;milestones_url;open_issues;watchers_count;git_refs_url;license;issues_url;svn_url;has_wiki;archive_url;has_issues;open_issues_count;downloads_url;pulls_url;owner;url;homepage;topics;created_at;clone_url;merges_url;branches_url;updated_at;git_tags_url;has_pages;forks_url;pushed_at;teams_url;has_projects;has_discussions;compare_url
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 95 columns]

# %%
from collections import Counter

# Combine all rows into a single string
all_text = ' '.join(data['language'].dropna())

# Split the text into words and count occurrences
word_count = Counter(all_text.split())

# Display the word count
print(word_count)
# Out:
# Counter({'Python': 309, 'R': 141, 'JavaScript': 131, 'Java': 110, 'PHP': 87, 'Jupyter': 74, 'Notebook': 74, 'C++': 62, 'TypeScript': 47, 'MATLAB': 46, 'TeX': 39, 'Rust': 36, 'C': 32, 'HTML': 26, 'Smalltalk': 25, 'C#': 20, 'Shell': 9, 'CSS': 8, 'Vue': 7, 'ASP': 6, 'Matlab': 6, 'Ruby': 5, 'Dockerfile': 5, 'XSLT': 4, 'AGS': 3, 'Script': 3, 'Common': 3, 'Lisp': 3, 'CLIPS': 3, 'Haskell': 3, 'PostScript': 3, 'Rich': 2, 'Text': 2, 'Format': 2, 'Kotlin': 2, 'GDScript': 2, 'GAMS': 2, 'PLpgSQL': 2, 'SCSS': 1, 'Dart': 1, 'Smarty': 1, 'RobotFramework': 1, 'StringTemplate': 1, 'FORTRAN': 1, 'QML': 1, 'Fortran': 1, 'Gnuplot': 1, 'XQuery': 1, 'Clojure': 1})

# %%
# Assuming word_count has been generated as shown in previous snippets
import seaborn as sns

# Get the top N most common words for better visualization
top_n = 20
common_words = word_count.most_common(top_n)

words = [word[0] for word in common_words]
counts = [word[1] for word in common_words]

# Plotting
plt.figure(figsize=(12, 8))
sns.barplot(x=words, y=counts)
plt.xticks(rotation=45)
plt.ylabel('Count')
plt.title(f'Top {top_n} Word Count in "language" column')
plt.savefig('languages.png', bbox_inches='tight')  # Save the plot as an image
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

def count_values_by_fair_score(dataframe, column_name):
    # Group by 'fair_score' and the given column, then count occurrences
    grouped = dataframe.groupby(['fair_score', column_name]).size().unstack()
    return grouped

if __name__ == "__main__":
    # Read the CSV file
    file_name = "combined.csv"
    data = pd.read_csv(file_name)

    columns_to_check = ["automated_testing", "test_folder", "actions"]
    results = {}

    # Count True/False values for each column based on 'fair_score' values
    for col in columns_to_check:
        results[col] = count_values_by_fair_score(data, col)

    # Print and visualize the results
    for col, result_df in results.items():
        print(f"\nCounts of True/False for {col} by fair_score:")
        print(result_df)

        # Visualization
        result_df.plot(kind='bar', stacked=True, figsize=(10, 6))
        plt.ylabel('Count')
        plt.title(f"Counts of True/False for {col} by fair_score")
        plt.grid(axis='y')
        plt.legend(title=col)
        plt.show()
# Out:
# Counts of True/False for automated_testing by fair_score:
# automated_testing  False  True
# fair_score
# 1.0                492.0    NaN
# 2.0                501.0    6.0
# 3.0                 30.0    1.0
# 4.0                  1.0    3.0
# Counts of True/False for test_folder by fair_score:
# test_folder  False  True
# fair_score
# 1.0          484.0    8.0
# 2.0          466.0   41.0
# 3.0           25.0    6.0
# 4.0            NaN    4.0
# Counts of True/False for actions by fair_score:
# actions     False
# fair_score
# 1.0           556
# 2.0           541
# 3.0            35
# 4.0             4

# %%
import pandas as pd
import matplotlib.pyplot as plt

def count_values_by_fair_score(dataframe, column_name):
    # Group by 'fair_score' and the given column, then count occurrences
    grouped = dataframe.groupby(['fair_score', column_name]).size().unstack().fillna(0)
    return grouped

if __name__ == "__main__":
    # Read the CSV file
    file_name = "combined.csv"
    data = pd.read_csv(file_name)

    columns_to_check = ["automated_testing", "test_folder", "actions"]
    results = {}

    # Ensure all values from 0 to 5 are present in fair_score column
    for i in range(6):
        if i not in data['fair_score'].unique():
            data = pd.concat([data, pd.DataFrame({'fair_score': [i]})])

    # Count True/False values for each column based on 'fair_score' values
    for col in columns_to_check:
        results[col] = count_values_by_fair_score(data, col)

    # Print and visualize the results
    for col, result_df in results.items():
        print(f"\nCounts of True/False for {col} by fair_score:")
        print(result_df)

        # Visualization
        result_df.plot(kind='bar', stacked=True, figsize=(10, 6))
        plt.ylabel('Count')
        plt.title(f"Counts of True/False for {col} by fair_score")
        plt.grid(axis='y')
        plt.legend(title=col, loc='upper right')
        plt.tight_layout()
        plt.show()
# Out:
# Counts of True/False for automated_testing by fair_score:
# automated_testing  False  True
# fair_score
# 1.0                492.0    0.0
# 2.0                501.0    6.0
# 3.0                 30.0    1.0
# 4.0                  1.0    3.0
# Counts of True/False for test_folder by fair_score:
# test_folder  False  True
# fair_score
# 1.0          484.0    8.0
# 2.0          466.0   41.0
# 3.0           25.0    6.0
# 4.0            0.0    4.0
# Counts of True/False for actions by fair_score:
# actions     False
# fair_score
# 1.0           556
# 2.0           541
# 3.0            35
# 4.0             4

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Step 1: Read the CSV file
data = pd.read_csv('combined.csv')

# Step 2: Filter the rows
filtered_data = data[(data["automated_testing"] == True) & (data["test_folder"] == True)]

# Step 3: Print the specified columns
print(filtered_data[["fair_score", "organisation", "researchGroup"]])

# Step 4: Display the "description"
print("\nDescriptions:")
for desc in filtered_data["description"]:
    print(desc)

# Step 5: Display some basic graphs
# As an example, let's plot a bar chart of "fair_score" grouped by "organisation"
grouped_data = filtered_data.groupby("organisation")["fair_score"].mean()
grouped_data.plot(kind="bar", title="Average fair_score by Organisation")
plt.ylabel("Fair Score")
plt.show()

# You can extend this to create other plots as per your needs
# Out:
#       fair_score                 organisation             researchGroup
# 1519         4.0  helmholz_center-gfz_potsdam           geosciences_gfz
# 1520         4.0  helmholz_center-gfz_potsdam           geosciences_gfz
# 1521         4.0  helmholz_center-gfz_potsdam           geosciences_gfz
# 1677         2.0     alfred-wegener_institute  earth_system_diagnostics
# 1678         2.0     alfred-wegener_institute  earth_system_diagnostics
# 1679         2.0     alfred-wegener_institute  earth_system_diagnostics
#
# Descriptions:
# Spectral homogenization of multispectral satellite data.
# AROSICS - Automated and Robust Open-Source Image Co-Registration Software
# EnMAP Processing Tool - A Python package for pre-processing of EnMAP Level-1B data
# An R package of tools for statistical analyses
# An R package of tools to assist with proxy analyses
# An R package of tools to handle NetCDF files
