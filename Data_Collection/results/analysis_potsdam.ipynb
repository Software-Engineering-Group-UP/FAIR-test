# %% [markdown]
# Analyis of opensource research organisations and their research group repositories

# %% [markdown]
# Import required libraries

# %%
# Importing necessary libraries for visualization
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# %% [markdown]
# Datasets

# %%
# Importing necessary libraries
import pandas as pd

# Reload the CSV file into a DataFrame
df = pd.read_csv('combined.csv')

# Display basic information about the DataFrame
df_info = df.info()

# Display first few rows of the DataFrame
df_head = df.head()

# Show basic statistics of numerical columns
df_describe = df.describe()

df_info, df_head, df_describe
# Filtering out the relevant columns for the analysis, including 'has_issues'
relevant_columns_with_issues = ['organisation', 'forks_count', 'stargazers_count', 'watchers', 'fork', 'has_issues', 'language']
df_filtered = df[relevant_columns]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 943 entries, 0 to 942
# Data columns (total 93 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         943 non-null    object
#  1   owner                        943 non-null    object
#  2   description                  737 non-null    object
#  3   language                     659 non-null    object
#  4   forks_count                  943 non-null    int64
#  5   stargazers_count             943 non-null    int64
#  6   events_url                   943 non-null    object
#  7   tags_url                     943 non-null    object
#  8   private                      943 non-null    bool
#  9   notifications_url            943 non-null    object
#  10  blobs_url                    943 non-null    object
#  11  deployments_url              943 non-null    object
#  12  keys_url                     943 non-null    object
#  13  archived                     943 non-null    bool
#  14  ssh_url                      943 non-null    object
#  15  watchers                     943 non-null    int64
#  16  forks                        943 non-null    int64
#  17  contributors_url             943 non-null    object
#  18  releases_url                 943 non-null    object
#  19  id                           943 non-null    int64
#  20  disabled                     943 non-null    bool
#  21  permissions                  943 non-null    object
#  22  languages_url                943 non-null    object
#  23  git_commits_url              943 non-null    object
#  24  visibility                   943 non-null    object
#  25  labels_url                   943 non-null    object
#  26  fork                         943 non-null    bool
#  27  trees_url                    943 non-null    object
#  28  mirror_url                   0 non-null      float64
#  29  is_template                  943 non-null    bool
#  30  web_commit_signoff_required  943 non-null    bool
#  31  issue_events_url             943 non-null    object
#  32  subscription_url             943 non-null    object
#  33  stargazers_url               943 non-null    object
#  34  git_url                      943 non-null    object
#  35  node_id                      943 non-null    object
#  36  commits_url                  943 non-null    object
#  37  subscribers_url              943 non-null    object
#  38  allow_forking                943 non-null    bool
#  39  default_branch               943 non-null    object
#  40  has_downloads                943 non-null    bool
#  41  assignees_url                943 non-null    object
#  42  comments_url                 943 non-null    object
#  43  full_name                    943 non-null    object
#  44  hooks_url                    943 non-null    object
#  45  collaborators_url            943 non-null    object
#  46  contents_url                 943 non-null    object
#  47  statuses_url                 943 non-null    object
#  48  html_url                     943 non-null    object
#  49  size                         943 non-null    int64
#  50  issue_comment_url            943 non-null    object
#  51  milestones_url               943 non-null    object
#  52  open_issues                  943 non-null    int64
#  53  watchers_count               943 non-null    int64
#  54  git_refs_url                 943 non-null    object
#  55  license                      471 non-null    object
#  56  issues_url                   943 non-null    object
#  57  svn_url                      943 non-null    object
#  58  has_wiki                     943 non-null    bool
#  59  archive_url                  943 non-null    object
#  60  has_issues                   943 non-null    bool
#  61  open_issues_count            943 non-null    int64
#  62  downloads_url                943 non-null    object
#  63  pulls_url                    943 non-null    object
#  64  owner.1                      943 non-null    object
#  65  url                          943 non-null    object
#  66  homepage                     84 non-null     object
#  67  topics                       943 non-null    object
#  68  created_at                   943 non-null    object
#  69  clone_url                    943 non-null    object
#  70  merges_url                   943 non-null    object
#  71  branches_url                 943 non-null    object
#  72  updated_at                   943 non-null    object
#  73  git_tags_url                 943 non-null    object
#  74  has_pages                    943 non-null    bool
#  75  forks_url                    943 non-null    object
#  76  pushed_at                    943 non-null    object
#  77  teams_url                    943 non-null    object
#  78  has_projects                 943 non-null    bool
#  79  has_discussions              943 non-null    bool
#  80  compare_url                  943 non-null    object
#  81  actions                      932 non-null    object
#  82  test_folder                  943 non-null    bool
#  83  automated_testing            943 non-null    bool
#  84  howfairis_repository         943 non-null    bool
#  85  howfairis_license            943 non-null    bool
#  86  howfairis_registry           943 non-null    bool
#  87  howfairis_citation           943 non-null    bool
#  88  howfairis_checklist          943 non-null    bool
#  89  date                         943 non-null    object
#  90  organisation                 943 non-null    object
#  91  researchGroup                943 non-null    object
#  92  fair_score                   943 non-null    int64
# dtypes: bool(20), float64(1), int64(10), object(62)
# memory usage: 556.4+ KB

# %% [markdown]
# Tree structure of research organisation used in this study with number of repositories

# %%
# Create a directed graph
G = nx.DiGraph()

# Add the central node
center_node = 'Potsdam'
G.add_node(center_node, label=center_node)

# Count research groups for each organization
org_group_count = df.groupby('organisation')['researchGroup'].count().to_dict()

# Add organizations to the graph
for org, count in org_group_count.items():
    G.add_node(org, label=f"{org}\n({count})")
    G.add_edge(center_node, org)

# Generate positions
pos = nx.spring_layout(G)

# Draw the graph
labels = nx.get_node_attributes(G, 'label')
nx.draw(G, pos, labels=labels, with_labels=True, node_color='skyblue', font_size=10, node_size=1000)
nx.draw_networkx_edges(G, pos, edgelist=G.edges(), edge_color='black', arrows=True)

plt.show()

# %% [markdown]
# Analysisng forks_count stargazers_count, wathcers, forks, has_issues with organisation, fair score, automated testing etc.

# %%
# Filtering out the relevant columns for the analysis
relevant_columns = ['organisation', 'language', 'forks_count', 'stargazers_count', 'watchers', 'fork', 'has_issues', 'fair_score']
df_filtered = df[relevant_columns]

# Calculating the average values for each organization
df_grouped = df_filtered.groupby('organisation').mean().reset_index()



# Grouping by 'organisation' and calculating the mean for each group
df_grouped_with_issues = df_filtered_with_issues.groupby('organisation').mean().reset_index()
# Out:
# /var/folders/80/92jv0gdd74n_p57srnsh1wcr0000gp/T/ipykernel_44171/2646142620.py:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_grouped = df_filtered.groupby('organisation').mean().reset_index()

# %% [markdown]
# # Analysis Organisation

# %% [markdown]
# 1. Average fork count by organisation
#
# This bar chart shows the average number of forks each organization's repositories have. It provides an idea of how much the code repositories are being forked for different organizations.

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='organisation', y='forks_count', data=df_grouped)
plt.title('Average Forks Count by Organisation')
plt.xlabel('Organisation')
plt.ylabel('Average Forks Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# 2. Average Stargazers count by organisation
#
# This bar chart shows the average number of stargazers each organization's repositories have. Stargazers could be considered a measure of a repository's popularity or quality.

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='organisation', y='stargazers_count', data=df_grouped)
plt.title('Average Stargazers Count by Organisation')
plt.xlabel('Organisation')
plt.ylabel('Average Stargazers Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# 3. Average Watchers Count by Organisation
#
# This bar chart shows the average number of watchers each organization's repositories have. Watchers are GitHub users who have opted to receive notifications for repository updates.

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='organisation', y='watchers', data=df_grouped)
plt.title('Average Watchers Count by Organisation')
plt.xlabel('Organisation')
plt.ylabel('Average Watchers Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# 4. Average Fork Indicator by Organisation
#
# This bar chart shows the average fork indicator for each organization's repositories. A higher value could mean that the repositories are primarily forks of other original repositories.

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='organisation', y='fork', data=df_grouped)
plt.title('Average Fork Indicator by Organisation')
plt.xlabel('Organisation')
plt.ylabel('Average Fork Indicator')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# 5. Average "Has Issues" Indicator by Organisation
#
# This bar chart shows the average has_issues indicator for each organization's repositories. A higher value could mean that the repositories are more likely to have issues, which is a good practice for collaborative development.

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='organisation', y='has_issues', data=df_grouped_with_issues)
plt.title('Average "Has Issues" Indicator by Organisation')
plt.xlabel('Organisation')
plt.ylabel('Average "Has Issues" Indicator')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Analysis based on FAIR score

# %%
# Filtering the DataFrame to include only these columns
df_filtered_with_fair_and_stats = df[relevant_columns]

# Grouping by 'fair_score' and calculating the mean for each group
df_grouped_with_fair_stats = df_filtered_with_fair_and_stats.groupby(['fair_score']).mean().reset_index()
# Out:
# /var/folders/80/92jv0gdd74n_p57srnsh1wcr0000gp/T/ipykernel_44171/3910261841.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_grouped_with_fair_stats = df_filtered_with_fair_and_stats.groupby(['fair_score']).mean().reset_index()

# %% [markdown]
# Plot 1: Average Forks Count by Fair Score

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='fair_score', y='forks_count', data=df_grouped_with_fair_stats)
plt.title('Average Forks Count by Fair Score')
plt.xlabel('Fair Score')
plt.ylabel('Average Forks Count')
plt.tight_layout()
plt.show()

# %% [markdown]
# Plot 2: Average Stargazers Count by Fair Score

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='fair_score', y='stargazers_count', data=df_grouped_with_fair_stats)
plt.title('Average Stargazers Count by Fair Score')
plt.xlabel('Fair Score')
plt.ylabel('Average Stargazers Count')
plt.tight_layout()
plt.show()

# %% [markdown]
# Plot 3: Average Watchers Count by Fair Score

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='fair_score', y='watchers', data=df_grouped_with_fair_stats)
plt.title('Average Watchers Count by Fair Score')
plt.xlabel('Fair Score')
plt.ylabel('Average Watchers Count')
plt.tight_layout()
plt.show()

# %% [markdown]
# Plot 4: Average "Has Issues" Indicator by Fair Score
#
# It is the average

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='fair_score', y='has_issues', data=df_grouped_with_fair_stats)
plt.title('Average "Has Issues" Indicator by Fair Score')
plt.xlabel('Fair Score')
plt.ylabel('Average "Has Issues" Indicator')
plt.tight_layout()
plt.show()

# %% [markdown]
# Plot 5: Average Fork Indicator by Fair Score

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='fair_score', y='fork', data=df_grouped_with_fair_stats)
plt.title('Average Fork Indicator by Fair Score')
plt.xlabel('Fair Score')
plt.ylabel('Average Fork Indicator')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Analysis based on Languages

# %% [markdown]
# Need further refining of data based on top 5 languages. Now it gives some garbage values in analysis

# %%
# Filtering the DataFrame to include only these columns
df_filtered_with_lang_and_stats = df[relevant_columns]

# Grouping by 'language' and calculating the mean for each group
df_grouped_with_lang_stats = df_filtered_with_lang_and_stats.groupby(['language']).mean().reset_index()
# Out:
# /var/folders/80/92jv0gdd74n_p57srnsh1wcr0000gp/T/ipykernel_44171/1581870794.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_grouped_with_lang_stats = df_filtered_with_lang_and_stats.groupby(['language']).mean().reset_index()

# %% [markdown]
# Plot 1: Average Forks Count by Language
# Note:- Need to clean common files like GAMS from the visualisation

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='language', y='forks_count', data=df_grouped_with_lang_stats)
plt.title('Average Forks Count by Language')
plt.xlabel('Language')
plt.ylabel('Average Forks Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Plot 2: Average Stargazers Count by Language
# Note:- Need to clean common files like GAMS from the visualisation

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='language', y='stargazers_count', data=df_grouped_with_lang_stats)
plt.title('Average Stargazers Count by Language')
plt.xlabel('Language')
plt.ylabel('Average Stargazers Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Plot 3: Average Watchers Count by Language
# Note:- Need to clean common files like GAMS from the visualisation

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='language', y='watchers', data=df_grouped_with_lang_stats)
plt.title('Average Watchers Count by Language')
plt.xlabel('Language')
plt.ylabel('Average Watchers Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Plot 4: Average "Has Issues" Indicator by Language
# Note:- Need to clean common files like GAMS from the visualisation

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='language', y='has_issues', data=df_grouped_with_lang_stats)
plt.title('Average "Has Issues" Indicator by Language')
plt.xlabel('Language')
plt.ylabel('Average "Has Issues" Indicator')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Plot 5: Average Fork Indicator by Language
# Note:- Need to clean common files like GAMS from the visualisation

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='language', y='fork', data=df_grouped_with_lang_stats)
plt.title('Average Fork Indicator by Language')
plt.xlabel('Language')
plt.ylabel('Average Fork Indicator')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Analysis on testing and automated testing

# %%
# Count the total number of repositories where 'test_folder' is True, 'automated_testing' is True, and both are True
count_test_folder_true = df[df['test_folder']].shape[0]
count_automated_testing_true = df[df['automated_testing']].shape[0]
count_both_true = df[df['test_folder'] & df['automated_testing']].shape[0]

count_test_folder_true, count_automated_testing_true, count_both_true

# Prepare data for visualization
count_data = {
    'Category': ['Presence of test folder', 'Presence of automated testig', 'Presence of automated testing'],
    'Count': [count_test_folder_true, count_automated_testing_true, count_both_true]
}

count_df = pd.DataFrame(count_data)

# Visualize the counts
plt.figure(figsize=(10, 6))
sns.barplot(x='Category', y='Count', data=count_df)
plt.title('Count of Repositories Based on Testing Features')
plt.xlabel('Category')
plt.ylabel('Count')
plt.tight_layout()
plt.show()

# %% [markdown]
# Testing and automated testing analysis with langauges

# %%
# Filter the DataFrame where both 'test_folder' and 'automated_testing' are True
df_filtered_both_true = df[df['test_folder'] & df['automated_testing']]

# Count the occurrences of each language under these conditions
count_by_lang_both_true = df_filtered_both_true.groupby('language').size().reset_index(name='Count')

# Visualize the counts by language
plt.figure(figsize=(12, 6))
sns.barplot(x='language', y='Count', data=count_by_lang_both_true)
plt.title('Count of Repos with Both Test Folder and Automated Testing by Language')
plt.xlabel('Language')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# visualise where automated_testing is true but test_folder is false
# There are some projects. where the test folder is absent but keyword test is present in make/ .yml file

# %%
# Filter the DataFrame where 'automated_testing' is True but 'test_folder' is False
df_filtered_auto_true_test_false = df[df['automated_testing'] & ~df['test_folder']]

# Count the occurrences of each language under these conditions
count_by_lang_auto_true_test_false = df_filtered_auto_true_test_false.groupby('language').size().reset_index(name='Count')


# Adjust the visualization to show only integer tick labels on the y-axis
plt.figure(figsize=(12, 6))
ax = sns.barplot(x='language', y='Count', data=count_by_lang_auto_true_test_false)
plt.title('Count of Repos with Automated Testing True but Test Folder False by Language (Integer Values)')
plt.xlabel('Language')
plt.ylabel('Count')
plt.xticks(rotation=45)

# Set y-ticks to integer values
ax.yaxis.set_major_locator(plt.MaxNLocator(integer=True))

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

def count_values_by_fair_score(dataframe, column_name):
    # Group by 'fair_score' and the given column, then count occurrences
    grouped = dataframe.groupby(['fair_score', column_name]).size().unstack()
    return grouped

if __name__ == "__main__":
    # Read the CSV file
    file_name = "combined.csv"
    data = pd.read_csv(file_name)

    columns_to_check = ["automated_testing", "test_folder", "actions"]
    results = {}

    # Count True/False values for each column based on 'fair_score' values
    for col in columns_to_check:
        results[col] = count_values_by_fair_score(data, col)

    # Print and visualize the results
    for col, result_df in results.items():
        print(f"\nCounts of True/False for {col} by fair_score:")
        print(result_df)

        # Visualization
        result_df.plot(kind='bar', stacked=True, figsize=(10, 6))
        plt.ylabel('Count')
        plt.title(f"Counts of True/False for {col} by fair_score")
        plt.grid(axis='y')
        plt.legend(title=col)
        plt.show()
# Out:
# Counts of True/False for automated_testing by fair_score:
# automated_testing  False  True
# fair_score
# 1                    452      3
# 2                    377     25
# 3                     24     17
# 4                     15     30
# Counts of True/False for test_folder by fair_score:
# test_folder  False  True
# fair_score
# 1              438     17
# 2              316     86
# 3               16     25
# 4                1     44
# Counts of True/False for actions by fair_score:
# actions     False
# fair_score
# 1             444
# 2             402
# 3              41
# 4              45

# %%
import pandas as pd
import matplotlib.pyplot as plt

def count_values_by_fair_score(dataframe, column_name):
    # Group by 'fair_score' and the given column, then count occurrences
    grouped = dataframe.groupby(['fair_score', column_name]).size().unstack().fillna(0)
    return grouped

if __name__ == "__main__":
    # Read the CSV file
    file_name = "combined.csv"
    data = pd.read_csv(file_name)

    columns_to_check = ["automated_testing", "test_folder", "actions"]
    results = {}

    # Ensure all values from 0 to 5 are present in fair_score column
    for i in range(6):
        if i not in data['fair_score'].unique():
            data = pd.concat([data, pd.DataFrame({'fair_score': [i]})])

    # Count True/False values for each column based on 'fair_score' values
    for col in columns_to_check:
        results[col] = count_values_by_fair_score(data, col)

    # Print and visualize the results
    for col, result_df in results.items():
        print(f"\nCounts of True/False for {col} by fair_score:")
        print(result_df)

        # Visualization
        result_df.plot(kind='bar', stacked=True, figsize=(10, 6))
        plt.ylabel('Count')
        plt.title(f"Counts of True/False for {col} by fair_score")
        plt.grid(axis='y')
        plt.legend(title=col, loc='upper right')
        plt.tight_layout()
        plt.show()
# Out:
# Counts of True/False for automated_testing by fair_score:
# automated_testing  False  True
# fair_score
# 1                    452      3
# 2                    377     25
# 3                     24     17
# 4                     15     30
# Counts of True/False for test_folder by fair_score:
# test_folder  False  True
# fair_score
# 1              438     17
# 2              316     86
# 3               16     25
# 4                1     44
# Counts of True/False for actions by fair_score:
# actions     False
# fair_score
# 1             444
# 2             402
# 3              41
# 4              45

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Step 1: Read the CSV file
data = pd.read_csv('combined.csv')

# Step 2: Filter the rows
filtered_data = data[(data["automated_testing"] == True) & (data["test_folder"] == True)]

# Step 3: Print the specified columns
print(filtered_data[["fair_score", "organisation", "researchGroup"]])

# Step 4: Display the "description"
print("\nDescriptions:")
for desc in filtered_data["description"]:
    print(desc)

# Step 5: Display some basic graphs
# As an example, let's plot a bar chart of "fair_score" grouped by "organisation"
grouped_data = filtered_data.groupby("organisation")["fair_score"].mean()
grouped_data.plot(kind="bar", title="Average fair_score by Organisation")
plt.ylabel("Fair Score")
plt.show()

# You can extend this to create other plots as per your needs
# Out:
#      fair_score                                       organisation  \
# 321           2                              university_of_potsdam
# 662           1                           hasso_plattner_institute
# 678           4      potsdam_institute_for_climate_impact_research
# 679           4      potsdam_institute_for_climate_impact_research
# 680           4      potsdam_institute_for_climate_impact_research
# 681           4      potsdam_institute_for_climate_impact_research
# 685           4      potsdam_institute_for_climate_impact_research
# 686           4      potsdam_institute_for_climate_impact_research
# 688           4      potsdam_institute_for_climate_impact_research
# 692           3      potsdam_institute_for_climate_impact_research
# 694           4      potsdam_institute_for_climate_impact_research
# 696           4      potsdam_institute_for_climate_impact_research
# 697           3      potsdam_institute_for_climate_impact_research
# 698           3      potsdam_institute_for_climate_impact_research
# 699           3      potsdam_institute_for_climate_impact_research
# 703           4      potsdam_institute_for_climate_impact_research
# 704           4      potsdam_institute_for_climate_impact_research
# 706           4      potsdam_institute_for_climate_impact_research
# 709           4      potsdam_institute_for_climate_impact_research
# 710           4      potsdam_institute_for_climate_impact_research
# 711           4      potsdam_institute_for_climate_impact_research
# 713           3      potsdam_institute_for_climate_impact_research
# 714           4      potsdam_institute_for_climate_impact_research
# 715           4      potsdam_institute_for_climate_impact_research
# 718           3      potsdam_institute_for_climate_impact_research
# 720           3      potsdam_institute_for_climate_impact_research
# 722           4      potsdam_institute_for_climate_impact_research
# 726           4      potsdam_institute_for_climate_impact_research
# 728           4      potsdam_institute_for_climate_impact_research
# 729           4      potsdam_institute_for_climate_impact_research
# 732           4      potsdam_institute_for_climate_impact_research
# 734           4      potsdam_institute_for_climate_impact_research
# 736           4      potsdam_institute_for_climate_impact_research
# 741           3      potsdam_institute_for_climate_impact_research
# 742           3      potsdam_institute_for_climate_impact_research
# 743           4      potsdam_institute_for_climate_impact_research
# 744           3      potsdam_institute_for_climate_impact_research
# 747           3      potsdam_institute_for_climate_impact_research
# 748           3      potsdam_institute_for_climate_impact_research
# 749           4      potsdam_institute_for_climate_impact_research
# 750           3      potsdam_institute_for_climate_impact_research
# 762           2      potsdam_institute_for_climate_impact_research
# 763           2      potsdam_institute_for_climate_impact_research
# 766           2      potsdam_institute_for_climate_impact_research
# 774           4      potsdam_institute_for_climate_impact_research
# 777           4                        helmholz_center-gfz_potsdam
# 778           4                        helmholz_center-gfz_potsdam
# 779           4                        helmholz_center-gfz_potsdam
# 787           2                        helmholz_center-gfz_potsdam
# 817           3                        helmholz_center-gfz_potsdam
# 831           3  berlin-brandenburgische_akademie_der_wissensch...
# 872           2  berlin-brandenburgische_akademie_der_wissensch...
# 878           2  berlin-brandenburgische_akademie_der_wissensch...
# 924           2                           alfred-wegener_institute
# 925           2                           alfred-wegener_institute
# 928           2                           alfred-wegener_institute
# 930           2                           alfred-wegener_institute
# 935           2                           alfred-wegener_institute
# 936           2                           alfred-wegener_institute
# 937           2                           alfred-wegener_institute
#
#                                          researchGroup
# 321                                           potassco
# 662                                   museum_barberini
# 678                                           pik-piam
# 679                                           pik-piam
# 680                                           pik-piam
# 681                                           pik-piam
# 685                                           pik-piam
# 686                                           pik-piam
# 688                                           pik-piam
# 692                                           pik-piam
# 694                                           pik-piam
# 696                                           pik-piam
# 697                                           pik-piam
# 698                                           pik-piam
# 699                                           pik-piam
# 703                                           pik-piam
# 704                                           pik-piam
# 706                                           pik-piam
# 709                                           pik-piam
# 710                                           pik-piam
# 711                                           pik-piam
# 713                                           pik-piam
# 714                                           pik-piam
# 715                                           pik-piam
# 718                                           pik-piam
# 720                                           pik-piam
# 722                                           pik-piam
# 726                                           pik-piam
# 728                                           pik-piam
# 729                                           pik-piam
# 732                                           pik-piam
# 734                                           pik-piam
# 736                                           pik-piam
# 741                                           pik-piam
# 742                                           pik-piam
# 743                                           pik-piam
# 744                                           pik-piam
# 747                                           pik-piam
# 748                                           pik-piam
# 749                                           pik-piam
# 750                                             remind
# 762                                           pik-gane
# 763                                           pik-gane
# 766                                           pik-gane
# 774                                        LPJmL_group
# 777                                    geosciences_gfz
# 778                                    geosciences_gfz
# 779                                    geosciences_gfz
# 787                       center_for_early_warning_gfz
# 817                                      fastscape_lem
# 831                                             telota
# 872  zentrum_für_digitale_lexikographie_der_deutsch...
# 878  zentrum_für_digitale_lexikographie_der_deutsch...
# 924                           earth_system_diagnostics
# 925                           earth_system_diagnostics
# 928                           earth_system_diagnostics
# 930                           earth_system_diagnostics
# 935                           earth_system_diagnostics
# 936                           earth_system_diagnostics
# 937                           earth_system_diagnostics
#
# Descriptions:
# A translator for logic programs with constraint atoms to CASP.
# A suite of data mining, analytics, and visualization solutions for analyzing museum data
# R package | May All Data be Reproducible and Transparent (MADRaT)
# R package | Data Class and Tools for Handling Spatial-Temporal Data
# Model intercomparison visualization package
# R package | MAgPIE outputs R package for MAgPIE version 4.x
# R package | Landuse Scaling Tools
# Documentation package for modular GAMS code
# R package | create cff citation file from R package metadata
# Some useful functions to plot data such as a map plot function for     MAgPIE objects.
# Package contains routines to prepare data for validation exercises.
# Package containing the LPJ-Object-Class together with relevant functions and methods.
# Bits and pieces of code to use with quitte-style data frames
# Contains the LIMES-specific routines for data and model output manipulation.
# Tools for data.table objects in the REMIND context. (Dis-)Aggregation, magpie conversion, interpolation etc.
# nan
# The mrremind packages contains data preprocessing for the REMIND model.
# nan
# A collection of tools which allow to manipulate and analyze code.
# nan
# The package provides cellular magpie related data via the madrat framework.
# A detailed transport sector model.
# Tool for easy handling of FABLE project data (India Foodcrop)
# MAgPIE water preprocessing
# The remind2 package contains the REMIND-specific routines for data and model output manipulation.
# A collection of tools for monitoring and diagnosing models
# R package for GDP unit conversion
# Create GDP and population scenarios
# nan
# nan
# Output routines for extracting results from the MAgPIE framework (versions 4.x) for the FSDP project
# Generate warming pathways using MAGICC for your MAgPIE runs using reference REMIND emissions
# Run different simple climate models from R using a unified interface
# nan
# nan
# Plotting functions for water-specific output analysis of mrwater library
# nan
# nan
# nan
# nan
# REMIND - REgional Model of INvestments and Development
# PyTorch version of Stable Baselines, reliable implementations of reinforcement learning algorithms.
# Contrib package for Stable-Baselines3 -  Experimental reinforcement learning (RL) code
# python package for torch-based neural network version of MoTaBaR
# A collection of basic functions to facilitate the work with the DGVM LPJmL hosted at the Potsdam Institute for Climate Impact Research.     It provides functions for running LPJmL, as well as reading, processing and writing model-related data such as inputs and outputs or configuration files.
# Spectral homogenization of multispectral satellite data.
# AROSICS - Automated and Robust Open-Source Image Co-Registration Software
# EnMAP Processing Tool - A Python package for pre-processing of EnMAP Level-1B data
# SATEX is a QGIS plugin to process LANDSAT satellite images
# nan
# Reduce Arabic strings to their rasm, i.e. remove vocalization and other diacritics
# IMS Neural Dependency Parser
# SFST/SMOR/DWDS-based German Morphology
# nan
# An R package to analyse and plot trench-like proxy records.
# PaleoSpec is an R package to assist the analysis of variance and power spectra
# An R package to analyse gridded field data.
# An R package of tools for statistical analyses
# An R package of tools to assist with proxy analyses
# An R package of tools to handle NetCDF files

# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# Read the CSV file into a DataFrame
df = pd.read_csv('combined.csv')

# Create a directed graph
G = nx.DiGraph()

# Add the center node
center_node = "Potsdam"
G.add_node(center_node)

# Populate the graph from the DataFrame
for index, row in df.iterrows():
    org = row['organisation']
    group = row['researchGroup']

    G.add_node(org)
    G.add_node(group)

    G.add_edge(org, group)
    G.add_edge(center_node, org)

# Draw the combined graph
plt.figure(figsize=(12, 12))  # Set figure size for better visibility
pos = nx.spring_layout(G)  # positions for all nodes
nx.draw(G, pos, with_labels=True, node_color="skyblue", font_weight="bold", node_size=2000, font_size=18)
plt.title("Combined Tree Diagram Centered Around Potsdam")
plt.show()

# %%
# Read the CSV into a DataFrame
df = pd.read_csv('combined.csv')

# %%
# Import additional visualization libraries
import matplotlib.colors as mcolors

# Initialize a 3x2 grid of subplots with larger size for better visuals
fig, axes = plt.subplots(3, 2, figsize=(25, 24), subplot_kw={'aspect': 'auto'})

# Create a colormap for a better visual experience
colormap = plt.cm.get_cmap('tab10')

# Plot 1: Distribution of test_folder by Programming Language with a pie chart
lang_test_folder = df.groupby(['language', 'test_folder']).size().unstack().fillna(0)
lang_test_folder.plot(kind='bar', stacked=True, colormap=colormap, ax=axes[0, 0])
axes[0, 0].set_title('Distribution of Test Folders by Programming Language')
axes[0, 0].set_ylabel('Number of Repositories')

# Plot 2: Distribution of automated_testing by Programming Language with a pie chart
lang_auto_test = df.groupby(['language', 'automated_testing']).size().unstack().fillna(0)
lang_auto_test.plot(kind='bar', stacked=True, colormap=colormap, ax=axes[0, 1])
axes[0, 1].set_title('Distribution of CI/CD Implementation by Programming Language')
axes[0, 1].set_ylabel('Number of Repositories')

# Plot 3: Distribution of test_folder by Organisation with a donut chart
org_test_folder = df.groupby(['organisation', 'test_folder']).size().unstack().fillna(0)
org_test_folder.plot(kind='bar', stacked=True, colormap=colormap, ax=axes[1, 0])
axes[1, 0].set_title('Distribution of Test Folders by Organisation')
axes[1, 0].set_ylabel('Number of Repositories')

# Plot 4: Distribution of automated_testing by Organisation with a donut chart
org_auto_test = df.groupby(['organisation', 'automated_testing']).size().unstack().fillna(0)
org_auto_test.plot(kind='bar', stacked=True, colormap=colormap, ax=axes[1, 1])
axes[1, 1].set_title('Distribution of CI/CD Implementation by Organisation')
axes[1, 1].set_ylabel('Number of Repositories')

# Plot 5: Distribution of test_folder by Research Group with a donut chart
if 'test_folder' in df.columns and 'researchGroup' in df.columns:
    rg_test_folder = df.groupby(['researchGroup', 'test_folder']).size().unstack().fillna(0)
    rg_test_folder.plot(kind='bar', stacked=True, colormap=colormap, ax=axes[2, 0])
    axes[2, 0].set_title('Distribution of Test Folders by Research Group')
    axes[2, 0].set_ylabel('Number of Repositories')

# Plot 6: Distribution of automated_testing by Research Group with a donut chart
if 'automated_testing' in df.columns and 'researchGroup' in df.columns:
    rg_auto_test = df.groupby(['researchGroup', 'automated_testing']).size().unstack().fillna(0)
    rg_auto_test.plot(kind='bar', stacked=True, colormap=colormap, ax=axes[2, 1])
    axes[2, 1].set_title('Distribution of CI/CD Implementation by Research Group')
    axes[2, 1].set_ylabel('Number of Repositories')

# Adjust layout and legend
plt.tight_layout()
plt.show()
# Out:
# /var/folders/80/92jv0gdd74n_p57srnsh1wcr0000gp/T/ipykernel_40926/4225599242.py:8: MatplotlibDeprecationWarning:
#
# The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
