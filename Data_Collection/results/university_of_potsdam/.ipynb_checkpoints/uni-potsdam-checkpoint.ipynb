# %%
import pandas as pd

# Load the CSV file
file_path = 'combined.csv'  # replace with the path to your file
data = pd.read_csv(file_path)

# Print column count and column names
column_count = len(data.columns)
print(f"Number of Columns: {column_count}")
print(f"Column Names: {data.columns.tolist()}")

# Display the first 5 rows
data.head()
# Out:
# Number of Columns: 94
# Column Names: ['name', 'owner', 'description', 'language', 'forks_count', 'stargazers_count', 'events_url', 'tags_url', 'private', 'notifications_url', 'blobs_url', 'deployments_url', 'keys_url', 'archived', 'ssh_url', 'watchers', 'forks', 'contributors_url', 'releases_url', 'id', 'disabled', 'permissions', 'languages_url', 'git_commits_url', 'visibility', 'labels_url', 'fork', 'trees_url', 'mirror_url', 'is_template', 'web_commit_signoff_required', 'issue_events_url', 'subscription_url', 'stargazers_url', 'git_url', 'node_id', 'commits_url', 'subscribers_url', 'allow_forking', 'default_branch', 'has_downloads', 'assignees_url', 'comments_url', 'full_name', 'hooks_url', 'collaborators_url', 'contents_url', 'statuses_url', 'html_url', 'size', 'issue_comment_url', 'milestones_url', 'open_issues', 'watchers_count', 'git_refs_url', 'license', 'issues_url', 'svn_url', 'has_wiki', 'archive_url', 'has_issues', 'open_issues_count', 'downloads_url', 'pulls_url', 'owner.1', 'url', 'homepage', 'topics', 'created_at', 'clone_url', 'merges_url', 'branches_url', 'updated_at', 'git_tags_url', 'has_pages', 'forks_url', 'pushed_at', 'teams_url', 'has_projects', 'has_discussions', 'compare_url', 'actions', 'test_folder', 'automated_testing', 'howfairis_repository', 'howfairis_license', 'howfairis_registry', 'howfairis_citation', 'howfairis_checklist', 'date', 'organisation', 'researchGroup', 'test', 'fair_score']
#                                             name  \
# 0                                    pymovements
# 1                                  etra-fairness
# 2                     etra-reading-comprehension
# 3                                      ecml-ADHD
# 4  neurips-gmml-2022-xai-eye-tracking-evaluation
#
#                                                owner  \
# 0  {'login': 'aeye-lab', 'id': 96292985, 'node_id...
# 1  {'login': 'aeye-lab', 'id': 96292985, 'node_id...
# 2  {'login': 'aeye-lab', 'id': 96292985, 'node_id...
# 3  {'login': 'aeye-lab', 'id': 96292985, 'node_id...
# 4  {'login': 'aeye-lab', 'id': 96292985, 'node_id...
#
#                                          description          language  \
# 0  A python package for processing eye movement data            Python
# 1                                                NaN  Jupyter Notebook
# 2                                                NaN            Python
# 3                                                NaN            Python
# 4                                                NaN            Python
#
#    forks_count  stargazers_count  \
# 0            3                24
# 1            0                 1
# 2            0                 4
# 3            2                 6
# 4            0                 1
#
#                                           events_url  \
# 0  https://api.github.com/repos/aeye-lab/pymoveme...
# 1  https://api.github.com/repos/aeye-lab/etra-fai...
# 2  https://api.github.com/repos/aeye-lab/etra-rea...
# 3  https://api.github.com/repos/aeye-lab/ecml-ADH...
# 4  https://api.github.com/repos/aeye-lab/neurips-...
#
#                                             tags_url  private  \
# 0  https://api.github.com/repos/aeye-lab/pymoveme...    False
# 1  https://api.github.com/repos/aeye-lab/etra-fai...    False
# 2  https://api.github.com/repos/aeye-lab/etra-rea...    False
# 3  https://api.github.com/repos/aeye-lab/ecml-ADH...    False
# 4  https://api.github.com/repos/aeye-lab/neurips-...    False
#
#                                    notifications_url  ...  \
# 0  https://api.github.com/repos/aeye-lab/pymoveme...  ...
# 1  https://api.github.com/repos/aeye-lab/etra-fai...  ...
# 2  https://api.github.com/repos/aeye-lab/etra-rea...  ...
# 3  https://api.github.com/repos/aeye-lab/ecml-ADH...  ...
# 4  https://api.github.com/repos/aeye-lab/neurips-...  ...
#
#   howfairis_repository howfairis_license howfairis_registry  \
# 0                 True              True               True
# 1                 True             False              False
# 2                 True             False              False
# 3                 True             False              False
# 4                 True             False              False
#
#    howfairis_citation howfairis_checklist        date           organisation  \
# 0               False               False  2023-08-11  university_of_potsdam
# 1               False               False  2023-08-11  university_of_potsdam
# 2               False               False  2023-08-11  university_of_potsdam
# 3               False               False  2023-08-11  university_of_potsdam
# 4               False               False  2023-08-11  university_of_potsdam
#
#   researchGroup test  fair_score
# 0          aeya  NaN         NaN
# 1          aeya  NaN         NaN
# 2          aeya  NaN         NaN
# 3          aeya  NaN         NaN
# 4          aeya  NaN         NaN
#
# [5 rows x 94 columns]

# %%
from collections import Counter

# Combine all rows into a single string
all_text = ' '.join(data['language'].dropna())

# Split the text into words and count occurrences
word_count = Counter(all_text.split())

# Display the word count
print(word_count)
# Out:
# Counter({'Python': 158, 'JavaScript': 62, 'PHP': 54, 'Java': 52, 'C++': 32, 'Rust': 24, 'TeX': 20, 'TypeScript': 20, 'Jupyter': 18, 'Notebook': 18, 'C': 16, 'R': 10, 'HTML': 6, 'ASP': 4, 'CSS': 4, 'C#': 4, 'Matlab': 4, 'AGS': 2, 'Script': 2, 'Common': 2, 'Lisp': 2, 'CLIPS': 2, 'Haskell': 2, 'PostScript': 2, 'XSLT': 2, 'Dockerfile': 2, 'MATLAB': 2, 'Ruby': 2, 'Shell': 2})

# %%
# Assuming word_count has been generated as shown in previous snippets

# Get the top N most common words for better visualization
top_n = 20
common_words = word_count.most_common(top_n)

words = [word[0] for word in common_words]
counts = [word[1] for word in common_words]

# Plotting
plt.figure(figsize=(12, 8))
sns.barplot(x=words, y=counts)
plt.xticks(rotation=45)
plt.ylabel('Count')
plt.title(f'Top {top_n} Word Count in "language" column')
plt.savefig('languages.png', bbox_inches='tight')  # Save the plot as an image
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

def count_values_by_fair_score(dataframe, column_name):
    # Group by 'fair_score' and the given column, then count occurrences
    grouped = dataframe.groupby(['fair_score', column_name]).size().unstack()
    return grouped

if __name__ == "__main__":
    # Read the CSV file
    file_name = "combined.csv"
    data = pd.read_csv(file_name)

    columns_to_check = ["automated_testing", "test_folder", "actions"]
    results = {}

    # Count True/False values for each column based on 'fair_score' values
    for col in columns_to_check:
        results[col] = count_values_by_fair_score(data, col)

    # Print and visualize the results
    for col, result_df in results.items():
        print(f"\nCounts of True/False for {col} by fair_score:")
        print(result_df)

        # Visualization
        result_df.plot(kind='bar', stacked=True, figsize=(10, 6))
        plt.ylabel('Count')
        plt.title(f"Counts of True/False for {col} by fair_score")
        plt.grid(axis='y')
        plt.legend(title=col)
        plt.show()
# Out:
# Counts of True/False for automated_testing by fair_score:
# automated_testing  False
# fair_score
# 1.0                   60
# 2.0                  108
# 3.0                    6
# Counts of True/False for test_folder by fair_score:
# test_folder  False  True
# fair_score
# 1.0           60.0    NaN
# 2.0          102.0    6.0
# 3.0            5.0    1.0
# Counts of True/False for actions by fair_score:
# actions     False
# fair_score
# 1.0            92
# 2.0           125
# 3.0             8

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 for value, language in zip(languages["language"].value_counts().head(10), languages["language"].value_counts().head(10).keys()):
#       2     percentage = value / len(repos) * 100
#       3     print("{} is present in {:.2f} % of all repositories". format(language, percentage))
#
# NameError: name 'languages' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as plt

def count_values_by_fair_score(dataframe, column_name):
    # Group by 'fair_score' and the given column, then count occurrences
    grouped = dataframe.groupby(['fair_score', column_name]).size().unstack().fillna(0)
    return grouped

if __name__ == "__main__":
    # Read the CSV file
    file_name = "combined.csv"
    data = pd.read_csv(file_name)

    columns_to_check = ["automated_testing", "test_folder", "actions"]
    results = {}

    # Ensure all values from 0 to 5 are present in fair_score column
    for i in range(6):
        if i not in data['fair_score'].unique():
            data = pd.concat([data, pd.DataFrame({'fair_score': [i]})])

    # Count True/False values for each column based on 'fair_score' values
    for col in columns_to_check:
        results[col] = count_values_by_fair_score(data, col)

    # Print and visualize the results
    for col, result_df in results.items():
        print(f"\nCounts of True/False for {col} by fair_score:")
        print(result_df)

        # Visualization
        result_df.plot(kind='bar', stacked=True, figsize=(10, 6))
        plt.ylabel('Count')
        plt.title(f"Counts of True/False for {col} by fair_score")
        plt.grid(axis='y')
        plt.legend(title=col, loc='upper right')
        plt.tight_layout()
        plt.show()
